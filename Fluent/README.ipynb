# %% [markdown]
# **[1. Problem's Physics & Theory](../Common_Files/Physics.ipynb)** | **[2. Domain's Creation & Discretization](./Domain.ipynb)**
# ------------- | -------------
# <img src="../Common_Files/Images/Flow_Schematic.jpg" width="350"> | <img src="../Common_Files/Images/CFD_domain_full.png" width="350">
# **[3. Simulation Case Setup](./Simulation.ipynb)** | **[4. Results Post-Process](./Post_Process.ipynb)**
# <img src="./Images/velocity_cont.png" width="350"> | <img src="./Images/velocity_profiles.png" width="350">
